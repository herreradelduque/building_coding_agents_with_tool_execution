# %% [markdown]
# # L2: Your First Coding Agent 🤖

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> , notebooks and other files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
#
# </div>

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI chat models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %% [markdown]
# First start by filtering warnings and loading environment variables.

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
from helper import load_env
load_env()

# %% [markdown]
# Try out a demo of the code generation agent below. You can try the prompt shown in the lesson here:
# > `Can you create a function for me that draws an emoji and runs it?`

# %%
cat demos.py
# Out:
# from lib.coding_agent import coding_agent as _coding_agent, log
# from openai import OpenAI
# from lib.utils import create_sandbox
# from lib.tools import execute_code
# from lib.tools_schemas import execute_code_schema
# from lib.logger import logger
# from lib.ui import ui
# import threading
#
#
# def coding_agent_demo_cli():
#     client = OpenAI()
#     sbx = create_sandbox()
#     messages = []
#     logger.info("✨: Hello there! Ask me to code something!")
#     while (query := input(">:")) != "/exit":
#         messages, usage = log(
#             _coding_agent,
#             query=query,
#             messages=messages,
#             client=client,
#             tools_schemas=[execute_code_schema],
#             system="You are senior Python software engineer",
#             tools={"execute_code": execute_code},
#             sbx=sbx,
#         )
#
#
# def coding_agent_demo_ui():
#     client = OpenAI()
#     sbx = create_sandbox()
#     messages = []
#     demo = ui(
#         _coding_agent,
#         messages=[],
#         client=client,
#         tools_schemas=[execute_code_schema],
#         system="You are senior Python software engineer",
#         tools={"execute_code": execute_code},
#         sbx=sbx,
#     )
#     demo.launch(height=800, share=True)

# %%
#!pip install e2b

# %%
#!pip install e2b-code-interpreter

# %%
#!pip install gradio

# %%
#!pip install gradio_browser

# %%
#!pip install gradio_aicontext

# %% [markdown]
# import os
# print(os.getenv("SOURCE_ROUTER_API_KEY"))
# print(os.getenv("CLAUDE_API_KEY"))
# print(os.getenv("E2B_API_KEY"))

# %%
from demos import coding_agent_demo_ui

coding_agent_demo_ui()
# Out:
# INFO     [sandbox] 🔌 Reconnecting to Sandbox.create(id=ijj1fnx4fvkplsgwc0kif)
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://e0a9dd3395f42f79ca.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e0a9dd3395f42f79ca.gradio.live" width="100%" height="800" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Language Model
#
# You can start building a coding agent yourself. Start by testing out a generic LLM call to make sure it's working. For simplicity, a function called `llm` is defined for you to handle the boilerplate code for calling the LLM.

# %%
from openai import OpenAI
from llm import llm

client = OpenAI()

messages = [{"role": "user", "content": "hi!"}]
system = "You speak like a linkedin influencer"

response = llm(client, messages, system)

response.output_text
# Out:
# 'Hello! 🌟 Thrilled to connect with you today. How can I help you elevate your journey to success? Let’s make every interaction count! 🚀'

# %% [markdown]
# ## Tools
#
# You can now create two important pieces of code:
# * `Execution`: A class that stores the results of the generated code and errors from your code generation agent.
# * `execute_code`: A function that takes any generated code as a string and outputs an `Execution` with the results (of the generated code) and/or any errors.

# %%
from typing import TypedDict
import sys
from io import StringIO


class Execution(TypedDict):
    results: list[str]
    errors: list[str]


def execute_code(code: str) -> Execution:
    execution = {"results": [], "errors": []}
    old_stdout = sys.stdout
    try:
        sys.stdout = StringIO()
        exec(code)
        result = sys.stdout.getvalue()
        sys.stdout = old_stdout
        execution["results"] = [result]
    except Exception as e:
        execution["errors"] = [str(e)]
    finally:
        sys.stdout = old_stdout
        return execution

# %% [markdown]
# Test it out by running the cell below.

# %%
execute_code("print('Hello World!')")
# Out:
# {'results': ['Hello World!\n'], 'errors': []}

# %% [markdown]
# You will now define this tool using the schema below and map it to the `tools` dictionary.

# %%
import json

execute_code_schema = {
    "type": "function",
    "name": "execute_code",
    "description": "Execute Python code and return the result or error.",
    "parameters": {
        "type": "object",
        "properties": {
            "code": {
                "type": "string",
                "description": "Python code to execute as a string",
            }
        },
        "required": ["code"],
        "additionalProperties": False,
    },
}

tools = {"execute_code": execute_code}

# %% [markdown]
# You will now create a function that executes tools and returns the results. It will take the following arguments:
#   * `name`: The name of the function
#   * `args`:  The arguments to be passed to the function
#   * `tools`: The dictionary with the tool mapping

# %%
tools
# Out:
# {'execute_code': <function __main__.execute_code(code: str) -> __main__.Execution>}

# %%
from typing import Callable
import json


def execute_tool(name: str, args: str, tools: dict[str, Callable]):
    try:
        args = json.loads(args)
        if name not in tools:
            return {"error": f"Tool {name} doesn't exist."}
        result = tools[name](**args)
    except json.JSONDecodeError as e:
        result = {"error": f"{name} failed to parse arguments: {str(e)}"}
    except KeyError as e:
        result = {"error": f"Missing key in arguments: {str(e)}"}
    except Exception as e:
        result = {"error": str(e)}
    return result

# %% [markdown]
# Now you can put the pieces together into the coding agent that will execute code! The coding agent will take the following arguments:
# * `client`: The LLM client you will use
# * `query`: The user query to the LLM
# * `system`: The system prompt for the LLM
# * `tools`: The dictionary mapping of the tools
# * `tools_schemas`: The tool schemas you defined for the LLM

# %%
def coding_agent(
    client: OpenAI,
    query: str,
    system: str,
    tools: dict[str, Callable],
    tools_schemas: list[dict],
):
    messages = [{"role": "user", "content": query}]
    response = llm(client, messages, system, tools=tools_schemas)
    for part in response.output:
        if part.type == "message":
            print(part.content)
        elif part.type == "function_call":
            name = part.name
            print(f"[{name}] executing...")
            result = execute_tool(name, part.arguments, tools)
            print(f"[{name}] {result}")

# %%
system = """You are a Senior Python programmer.
You must always use the `execute_code` tool to run code.
You collect user's inputs by using the `input` python function.
"""

query = """Make a program that asks how many cups of coffee you had today,
then converts that into lines of code written and prints them back.
Because caffeine = productivity."""

coding_agent(client,
             query,
             system,
             tools=tools,
             tools_schemas=[execute_code_schema])
# Out:
# [execute_code] executing...
# [execute_code] {'results': ['Because caffeine = productivity, you wrote approximately 100 lines of code today!\n'], 'errors': []}

# %% [markdown]
# ### File System
#
# Now that you have made your working code agent, you can give it more tools to give it the ability to do even more tasks. You will create two schemas and their associated functions to read and write files.
#
# In addition, you will create a `ToolError` class that will pass an exception back instead of the whole stack trace.

# %%
read_file_schema = {
    "type": "function",
    "name": "read_file",
    "description": "Reads content from a file with optional offset and limit for large files.",
    "parameters": {
        "type": "object",
        "properties": {
            "file_path": {
                "type": "string",
                "description": "Absolute path to the file to read",
            },
            "limit": {
                "type": "number",
                "description": "Maximum number of characters to read",
            },
            "offset": {
                "type": "number",
                "description": "Starting position in the file",
            },
        },
        "required": ["file_path"],
        "additionalProperties": False,
    },
}

# %%
write_file_schema = {
    "type": "function",
    "name": "write_file",
    "description": "Writes content to a file, creating directories if needed.",
    "parameters": {
        "type": "object",
        "properties": {
            "content": {
                "type": "string",
                "description": "Content to write to the file",
            },
            "file_path": {
                "type": "string",
                "description": "Absolute path where the file will be written",
            },
        },
        "required": ["content", "file_path"],
        "additionalProperties": False,
    },
}

# %%
from typing import Optional, Dict, Any

class ToolError(Exception):
    """Custom exception for tool failures"""
    pass

def read_file(
    file_path: str, limit: Optional[int] = None, offset: int = 0
) -> Dict[str, Any]:
    """Read file content with optional offset and limit."""
    if not os.path.exists(file_path):
        raise ToolError(f"File does not exist: {file_path}")

    if not os.path.isfile(file_path):
        raise ToolError(f"Path is not a file: {file_path}")

    try:
        with open(file_path, "r", encoding="utf-8", errors="replace") as f:
            if offset > 0:
                f.seek(offset)
            content = f.read(limit) if limit else f.read()

        return {"content": content, "size": len(content)}

    except PermissionError:
        raise ToolError(f"Permission denied: {file_path}")
    except UnicodeDecodeError:
        raise ToolError(f"Cannot decode file as UTF-8: {file_path}")

# %%
def write_file(content: str, file_path: str) -> Dict[str, Any]:
    """Write content to file, creating directories if needed."""
    try:
        directory = os.path.dirname(file_path)
        if directory:
            os.makedirs(directory, exist_ok=True)

        with open(file_path, "w", encoding="utf-8") as f:
            f.write(content)

        file_size = os.path.getsize(file_path)
        # we keep the result minimal
        return {
            "message": f"Written {file_size} bytes to {file_path}",
            "size": file_size,
        }

    except PermissionError:
        raise ToolError(f"Permission denied: {file_path}")

# %% [markdown]
# Now add these tools to the `tools` dictionary.

# %%
tools = {
    "execute_code": execute_code,
    "read_file": read_file,
    "write_file": write_file,
}

# %% [markdown]
# Let's try it out! Since you will be working with files on the computer, you will import `os` and create a directory to hold the files the agent creates.

# %%
import os

working_dir = os.getcwd() + "/agent_files"

os.makedirs(working_dir, exist_ok=True)

query = f"""Can you create a blank text.txt file?
Your current working directory is {working_dir}"""

coding_agent(
    client,
    query,
    system,
    tools=tools,
    tools_schemas=[execute_code_schema,
                   read_file_schema,
                   write_file_schema],
)
# Out:
# [execute_code] executing...
# [execute_code] {'results': [''], 'errors': []}

# %%
query = "Can you read not_exists.txt file and print the content?"

coding_agent(
    client,
    query,
    system,
    tools=tools,
    tools_schemas=[execute_code_schema,
                   read_file_schema,
                   write_file_schema],
)
# Out:
# [execute_code] executing...
# [execute_code] {'results': ["The file 'not_exists.txt' does not exist.\n"], 'errors': []}

# %%
query = """Can you:
1. Create a file1.txt file with 'file1'
2. Read file1.txt'
"""

coding_agent(
    client,
    query,
    system,
    tools=tools,
    tools_schemas=[execute_code_schema,
                   read_file_schema,
                   write_file_schema],
)
# Out:
# [write_file] executing...
# [write_file] {'message': 'Written 5 bytes to file1.txt', 'size': 5}
# [read_file] executing...
# [read_file] {'content': 'file1', 'size': 5}

# %% [markdown]
# ## Agent Loop
#
# Now it's time to create a loop for your coding agent so it knows when to stop. You will implement two stop conditions:
# * When the agent has reached `max_steps`
# * When the agent no longer calls functions
#
# By using `max_steps` you help the LLM avoid continually calling functions while not accomplishing its task. And if the agent no longer calls functions, you can assume that it has found the answer and no longer needs to augment its answers.

# %%
import json

def coding_agent(
    client: OpenAI,
    query: str,
    system: str,
    tools: dict[str, Callable],
    tools_schemas: list[dict],
    messages: list[dict] = None,
    max_steps: int = 5,
):
    if messages is None:
        messages = []
    messages.append({"role": "user", "content": query})
    steps = 0

    while steps < max_steps:
        response = llm(client, messages, system, tools=tools_schemas)
        print(f"[#{steps}-step]")
        has_function_call = False

        for part in response.output:
            messages.append(part)
            if part.type == "message":
                print(f"[agent] {response.output_text}")
            elif part.type == "function_call":
                has_function_call = True
                name = part.name
                print(f"[agent][{name}] executing...")
                result = execute_tool(name, part.arguments, tools)
                print(f"[{name}] {result}")
                messages.append(
                    {
                        "type": "function_call_output",
                        "call_id": part.call_id,
                        "output": json.dumps(result),
                    }
                )

        if not has_function_call:
            print("[agent] all tasks completed")
            break
        steps += 1

# %% [markdown]
# Try it out by creating a Caesar cipher program.

# %%
query = """Your task is:
1. Write me a caesar cipher function
2. Ask the user for a message
3. Ask the user for the cipher shift
4. Run the function with the user inputs
5. Print back the ciphered message
6. Save it to secret.txt file in the current folder
"""

coding_agent(
    client,
    query,
    system,
    tools=tools,
    tools_schemas=[execute_code_schema,
                   read_file_schema,
                   write_file_schema],
)
# Out:
# [#0-step]
# [agent][execute_code] executing...
# [execute_code] {'results': ['Ciphered message: mvvjt\n'], 'errors': []}
# [#1-step]
# [agent] I have written the Caesar cipher function, asked you for the message and the cipher shift, ran the function with your inputs, printed the ciphered message, and saved it to the file secret.txt in the current folder.
#
# If you want to try again or have any other requests, just let me know!
# [agent] all tasks completed

# %%
# !cat secret.txt
# Out:
# mvvjt

# %% [markdown]
# ## Chat Interface
#
# You can create a chat interface for your coding agent. This will run code for you. If you would like to exit the chat interface, use `/exit`.

# %%
messages = []

while (query := input(">:")) != "/exit":
    coding_agent(
        client,
        query,
        system,
        messages=messages,
        tools=tools,
        tools_schemas=[execute_code_schema,
                       read_file_schema,
                       write_file_schema],
    )
# Out:
# [#0-step]
# [agent] ¡Hola! ¿En qué puedo ayudarte hoy?
# [agent] all tasks completed

# %%
# 1) Función Python (no usar input)
def saludar_nombre(nombre: str) -> str:
    return f"¡Hola {nombre}! Encantado de saludarte."

# 2) Schema serializable para la API (IMPORTANTE: tiene function.name)
saludar_nombre_schema = {
    "type": "function",
    "function": {
        "name": "saludar_nombre",
        "description": "Saluda a una persona usando su nombre.",
        "parameters": {
            "type": "object",
            "properties": {
                "nombre": {
                    "type": "string",
                    "description": "El nombre de la persona a saludar."
                }
            },
            "required": ["nombre"]
        }
    }
}

# 3) Registrar en tools y tools_schemas (asegúrate de usar las variables correctas)
tools = {
    "execute_code": execute_code,
    "read_file": read_file,
    "write_file": write_file,
    "saludar_nombre": saludar_nombre
}

tools_schemas = [
    execute_code_schema,
    saludar_nombre_schema
]

# %%
print("tools types:", {k: type(v).__name__ for k,v in tools.items()})
print("tools_schemas types:", [type(s).__name__ for s in tools_schemas])
assert all(isinstance(s, dict) for s in tools_schemas), "ERROR: tools_schemas debe contener dicts (schemas), no funciones"
for s in tools_schemas:
    if "function" in s:
        assert "name" in s["function"], "ERROR: cada schema debe tener function.name definido"
# Out:
# tools types: {'execute_code': 'function', 'read_file': 'function', 'write_file': 'function', 'saludar_nombre': 'function'}
# tools_schemas types: ['dict', 'dict']

# %%
print("tools types:", {k: type(v).__name__ for k,v in tools.items()})
print("tools_schemas types:", [type(s).__name__ for s in tools_schemas])
assert all(isinstance(s, dict) for s in tools_schemas), "tools_schemas debe contener dicts (schemas), no funciones"
# Out:
# tools types: {'execute_code': 'function', 'read_file': 'function', 'write_file': 'function', 'saludar_nombre': 'function'}
# tools_schemas types: ['dict', 'dict']

# %%
coding_agent(
    client,
    query,
    system,
    tools=tools,                 # funciones Python
    tools_schemas=tools_schemas, # schemas serializables (dicts)
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 coding_agent(
#       2     client,
#       3     query,
#       4     system,
#       5     tools=tools,                 # funciones Python
#       6     tools_schemas=tools_schemas, # schemas serializables (dicts)
#       7 )
#
# Cell In[27], line 18, in coding_agent(client, query, system, tools, tools_schemas, messages, max_steps)
#      15 steps = 0
#      17 while steps < max_steps:
# ---> 18     response = llm(client, messages, system, tools=tools_schemas)
#      19     print(f"[#{steps}-step]")
#      20     has_function_call = False
#
# File ~/vscode_projects/building_coding_agents_with_tool_execution/notebooks/my_tests/L2/llm.py:15, in llm(client, messages, system, name, **kwargs)
#      13 if name.startswith("gpt-4"):
#      14     kwargs["temperature"] = 0
# ---> 15 response = client.responses.create(
#      16     model=name,
#      17     input=[system_message, *messages],
#      18     **kwargs,
#      19 )
#      20 return response
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.11/site-packages/openai/resources/responses/responses.py:898, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     859 def create(
#     860     self,
#     861     *,
#    (...)    896     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     897 ) -> Response | Stream[ResponseStreamEvent]:
# --> 898     return self._post(
#     899         "/responses",
#     900         body=maybe_transform(
#     901             {
#     902                 "background": background,
#     903                 "context_management": context_management,
#     904                 "conversation": conversation,
#     905                 "include": include,
#     906                 "input": input,
#     907                 "instructions": instructions,
#     908                 "max_output_tokens": max_output_tokens,
#     909                 "max_tool_calls": max_tool_calls,
#     910                 "metadata": metadata,
#     911                 "model": model,
#     912                 "parallel_tool_calls": parallel_tool_calls,
#     913                 "previous_response_id": previous_response_id,
#     914                 "prompt": prompt,
#     915                 "prompt_cache_key": prompt_cache_key,
#     916                 "prompt_cache_retention": prompt_cache_retention,
#     917                 "reasoning": reasoning,
#     918                 "safety_identifier": safety_identifier,
#     919                 "service_tier": service_tier,
#     920                 "store": store,
#     921                 "stream": stream,
#     922                 "stream_options": stream_options,
#     923                 "temperature": temperature,
#     924                 "text": text,
#     925                 "tool_choice": tool_choice,
#     926                 "tools": tools,
#     927                 "top_logprobs": top_logprobs,
#     928                 "top_p": top_p,
#     929                 "truncation": truncation,
#     930                 "user": user,
#     931             },
#     932             response_create_params.ResponseCreateParamsStreaming
#     933             if stream
#     934             else response_create_params.ResponseCreateParamsNonStreaming,
#     935         ),
#     936         options=make_request_options(
#     937             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     938         ),
#     939         cast_to=Response,
#     940         stream=stream or False,
#     941         stream_cls=Stream[ResponseStreamEvent],
#     942     )
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.11/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.11/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "Missing required parameter: 'tools[1].name'.", 'type': 'invalid_request_error', 'param': 'tools[1].name', 'code': 'missing_required_parameter'}}
